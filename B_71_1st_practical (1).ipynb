# %% [markdown]
# # 1.Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 2.Loading Dataset into the pandas dataframe

# %%
df=pd.read_csv("IPL Matches 2008-2020.csv")

# %% [markdown]
# ### Checking whether data is imported or not

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %% [markdown]
# # 3.Data Preprocessing

# %% [markdown]
# ### Checking Null Values

# %%
df.isnull()
# Out:
#         id   city   date  player_of_match  venue  neutral_venue  team1  team2  \
# 0    False  False  False            False  False          False  False  False
# 1    False  False  False            False  False          False  False  False
# 2    False  False  False            False  False          False  False  False
# 3    False  False  False            False  False          False  False  False
# 4    False  False  False            False  False          False  False  False
# ..     ...    ...    ...              ...    ...            ...    ...    ...
# 811  False  False  False            False  False          False  False  False
# 812  False  False  False            False  False          False  False  False
# 813  False  False  False            False  False          False  False  False
# 814  False  False  False            False  False          False  False  False
# 815  False  False  False            False  False          False  False  False
#
# ...

# %%
df.isnull().sum() #returns no of null values for each column
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %% [markdown]
# ### Checking Nan values

# %%
df.isna()
# Out:
#         id   city   date  player_of_match  venue  neutral_venue  team1  team2  \
# 0    False  False  False            False  False          False  False  False
# 1    False  False  False            False  False          False  False  False
# 2    False  False  False            False  False          False  False  False
# 3    False  False  False            False  False          False  False  False
# 4    False  False  False            False  False          False  False  False
# ..     ...    ...    ...              ...    ...            ...    ...    ...
# 811  False  False  False            False  False          False  False  False
# 812  False  False  False            False  False          False  False  False
# 813  False  False  False            False  False          False  False  False
# 814  False  False  False            False  False          False  False  False
# 815  False  False  False            False  False          False  False  False
#
# ...

# %%
df.isna().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df.fillna('dummy') #fills missing values with 'dummy'
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.isna().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %% [markdown]
# # Dropping a single column

# %%
df.drop(["city"],axis=1) #drop the "city" column from the DataFrame
# Out:
#           id        date player_of_match  \
# 0     335982  2008-04-18     BB McCullum
# 1     335983  2008-04-19      MEK Hussey
# 2     335984  2008-04-19     MF Maharoof
# 3     335985  2008-04-20      MV Boucher
# 4     335986  2008-04-20       DJ Hussey
# ..       ...         ...             ...
# 811  1216547  2020-09-28  AB de Villiers
# 812  1237177  2020-11-05       JJ Bumrah
# 813  1237178  2020-11-06   KS Williamson
# 814  1237180  2020-11-08      MP Stoinis
# 815  1237181  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ..                                          ...            ...
# ...

# %%
df["eliminator"].nunique() # calculates the number of unique values in the "eliminator" column
# Out:
# 2

# %% [markdown]
# #### Using Describe Function

# %%
df.describe() #returns descriptive statistics of just numerical columns
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %% [markdown]
# #### using info() function

# %%
#summary of the DataFrame df, including information about the data types, memory usage, and number of non-null values for each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# #### checking Dimensions of the data

# %%
df.shape #returns a tuple containing (n_rows, n_columns)
# Out:
# (816, 17)

# %% [markdown]
# # 4.Data Formating & Data Normalization

# %% [markdown]
# ### checking Datatypes

# %%
df.dtypes #provides the data types of each column
# Out:
# id                   int64
# city                object
# date                object
# player_of_match     object
# venue               object
# neutral_venue        int64
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# eliminator          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
df=df.astype({"date":"object"}) #converts the data type of the "date" column in the DataFrame to object type

# %%
df=df.astype({"neutral_venue":"float64"}) #converts the data type of the "neutral_venue" column in the DataFrame to float64

# %%
df.dtypes
# Out:
# id                   int64
# city                object
# date                object
# player_of_match     object
# venue               object
# neutral_venue      float64
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# eliminator          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %%
df["date"]=pd.to_datetime(df["date"]) #converts the values in the "date" column of the DataFrame to datetime objects

# %%
#ndim will always return 2 because a DataFrame is a two-dimensional data structure. It has rows and columns, so ndim will always be 2

# %%
df.ndim #dimensions
# Out:
# 2

# %%
df.dtypes
# Out:
# id                          int64
# city                       object
# date               datetime64[ns]
# player_of_match            object
# venue                      object
# neutral_venue             float64
# team1                      object
# team2                      object
# toss_winner                object
# toss_decision              object
# winner                     object
# result                     object
# result_margin             float64
# eliminator                 object
# method                     object
# umpire1                    object
# umpire2                    object
# dtype: object

# %% [markdown]
# # Extracting Rows

# %% [markdown]
# df['el'].replace(['Under-Graduate', 'Diploma '],
#                         [0, 1], inplace=True)

# %%
#"N" values are replaced with 0.
#"Y" values are replaced with 1.

# %%
df["eliminator"].replace(["N","Y"],[0,1],inplace=True)

# %%
df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium            0.0
# 1    Punjab Cricket Association Stadium, Mohali            0.0
# 2                              Feroz Shah Kotla            0.0
# 3                              Wankhede Stadium            0.0
# ...
